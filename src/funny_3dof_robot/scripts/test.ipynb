# %%
import numpy as np

# %%
x = 2
y = 0
z = 3
gamma1 = 1
gamma2 = 1


l1 = 2
l2 = 2.5
l3 = 2.8

# %%
def IK2DOF(x,y,gamma,l1,l2):
    if ((l2-l1) <= np.sqrt(x**2+y**2) and (l2+l1) >= np.sqrt(x**2+y**2)):
        c2 = (x**2+y**2-l1**2-l2**2)/(2*l1*l2)
    else:
        return -1
    s2 = gamma*np.sqrt(1-c2**2)

    q1 = np.arctan2(y,x) - np.arctan2(l2*s2 ,l1 + l2*c2)
    q2 = np.arctan2(s2, c2)

    return q1, q2

# %%
np.sqrt(x**2+y**2)
# Out:
# 2.0

# %%
q1 = np.arctan2(y/gamma1,x/gamma1)

# %%
q1
# Out:
# 0.0

# %%
q1 = np.arctan2(y/gamma1,x/gamma1)

r = gamma1 * np.sqrt(x**2+y**2)

q2, q3 = IK2DOF(r,
                z - l1,
                gamma2,
                l2,
                l3)

# %%
r
# Out:
# 2.0

# %%
print(q1,q2,q3)
# Out:
# 0.0 -0.7972106327886452 2.2774412099183414

# %%
import roboticstoolbox as rtb

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
pi =np.pi

# %%
# %matplotlib tk
robot = rtb.DHRobot([
            rtb.RevoluteMDH(a=0, alpha = 0, d=0.2),  #F1
            rtb.RevoluteMDH(a=0, alpha=-np.pi/2, d=-0.12 ,offset=-np.pi/2),
            rtb.RevoluteMDH(a=0.25,d=0.1), #F3
            
        ], name="robot")
robot.tool = SE3.Trans(0.28, 0.0, 0.0) * SE3.RPY(pi/2, 0, pi/2)
robot.plot([0,0,0])
# Out:
# PyPlot3D backend, t = 0.05, scene:
#   robot: Text(0.0, 0.0, 'robot')

# %%
q = np.array([0, 0, 0])

# %%
T = robot.fkine(q)
print(T)
# Out:
#    1         0         0         0
#    0         1         0        -0.02
#    0         0         1         0.73
#    0         0         0         1

# %%
from spatialmath import SE3

# %%
theta1 = np.random.uniform(0,2*np.pi,1)[0]
theta2 = np.random.uniform(0,2*np.pi,1)[0]
r = np.random.uniform(0.3,0.53,1)[0]
x = r*np.sin(theta1)*np.cos(theta2)
y = r*np.sin(theta1)*np.sin(theta2)
z = r*np.cos(theta1)

# %%
target_position = SE3.Trans(x,y,z)
T = SE3(target_position)
solution = robot.ikine_LM(T, mask=[1, 1, 1, 0, 0, 0])
solution.success
# Out:
# True

# %%
while(1):
    theta1 = np.random.uniform(0, np.pi)
    theta2 = np.random.uniform(0, 2 * np.pi)
    r = np.random.uniform(0.3, 0.53)
    x = r * np.sin(theta1) * np.cos(theta2)
    y = r * np.sin(theta1) * np.sin(theta2)
    z = r * np.cos(theta1)

    target_position = SE3.Trans(x,y,z)
    T = SE3(target_position)

    solution = robot.ikine_LM(T, mask=[1, 1, 1, 0, 0, 0],tol=0.1)
    print(" p")
    if not solution.success:
        break

solution.success
# Out:
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
#  p
# ...

# %%
r
# Out:
# 0.5197616231654532

# %%
np.sqrt(x**2 + y**2 + z**2)
# Out:
# 0.5281466055308887

# %%
while True:
    theta1 = np.random.uniform(0, np.pi)
    theta2 = np.random.uniform(0, 2 * np.pi)
    r = np.random.uniform(0.3, 0.53)
    x = r * np.sin(theta1) * np.cos(theta2)
    y = r * np.sin(theta1) * np.sin(theta2)
    z = r * np.cos(theta1)

    target_position = SE3.Trans(x, y, z)
    T = SE3(target_position)

    solution = robot.ikine_LM(T, mask=[1, 1, 1, 0, 0, 0], tol=0.01)
    distance = np.sqrt(x**2 + y**2 + z**2)
    if distance > 0.53:
        print(distance)
        print(x, y, z)
        print(theta1, theta2)
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[315], line 12
#       9 target_position = SE3.Trans(x, y, z)
#      10 T = SE3(target_position)
# ---> 12 solution = robot.ikine_LM(T, mask=[1, 1, 1, 0, 0, 0], tol=0.01)
#      13 distance = np.sqrt(x**2 + y**2 + z**2)
#      14 if distance > 0.53:
#
# File ~/.local/lib/python3.10/site-packages/roboticstoolbox/robot/DHRobot.py:2465, in DHRobot.ikine_LM(self, Tep, q0, ilimit, slimit, tol, joint_limits, mask, seed)
#    2454 def ikine_LM(
#    2455     self,
#    2456     Tep: Union[np.ndarray, SE3],
#    (...)
#    2463     seed: Union[int, None] = None,
#    2464 ):
# -> 2465     return self.ets().ikine_LM(
#    2466         Tep=Tep,
#    2467         q0=q0,
#    2468         ilimit=ilimit,
#    2469         slimit=slimit,
#    2470         tol=tol,
#    2471         joint_limits=joint_limits,
#    2472         mask=mask,
# ...

# %%
T
# Out:
#    1         0         0         0.1966
#    0         1         0        -0.03433
#    0         0         1        -0.3018
#    0         0         0         1

# %%
robot.fkine(solution.q)
# Out:
#    0.3871   -0.8697    0.3064    0.2002
#   -0.6819   -0.4937   -0.5398   -0.3122
#    0.6207    0        -0.7841   -0.174
#    0         0         0         1

# %%
T
# Out:
#    1         0         0         0.2333
#    0         1         0        -0.3648
#    0         0         1        -0.2335
#    0         0         0         1

# %%
robot.workspace
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 robot.workspace
#
# AttributeError: 'DHRobot' object has no attribute 'workspace'

# %%
solution
# Out:
# IKSolution(q=array([-2.49809092, -0.78018969, -2.48980409]), success=True, iterations=6, searches=1, residual=1.1931922774266756e-08, reason='Success')

# %%
np.round(solution.q, decimals=2)
# Out:
# array([-0.26, -2.62, -3.82,  1.28])

# %%
solution.q
# Out:
# array([-0.25816725, -2.61627494, -3.81822647,  1.27836607])

# %%
q
# Out:
# array([0, 0, 0, 0, 0])

# %%
robot.plot(solution.q)
# Out:
# PyPlot3D backend, t = 0.05, scene:
#   robot: Text(0.0, 0.0, 'robot')
